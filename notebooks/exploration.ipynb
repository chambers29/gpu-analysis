# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("../data/gpu_1986-2026.csv")
df.head()
# Out:
#   Brand                      Name Top__GRAPHICS PROCESSOR Top__PIXEL SHADERS  \
# 0   ATI      Color Emulation Card               CW16800-A                NaN
# 1   ATI         Graphics Solution               CW16800-A                NaN
# 2   ATI            EGA Wonder 800                 16899-0                  1
# 3   ATI    Graphics Solution Plus               CW16800-B                NaN
# 4   ATI  VGA Improved Performance                 16899-0                  1
#
#   Top__VERTEX SHADERS Top__TMUS Top__ROPS Top__MEMORY SIZE Top__MEMORY TYPE  \
# 0                 NaN       NaN       NaN            32 KB             DRAM
# 1                 NaN       NaN       NaN            64 KB             DRAM
# 2                 NaN       NaN         1           256 KB             DRAM
# 3                 NaN       NaN       NaN            64 KB             DRAM
# 4                 NaN       NaN         1           256 KB             DRAM
#
# ...

# %%
for column in df.columns:
    print(f"COLUMN NAME: {column:<50}{df.loc[1][column]:<30}{df[column].isna().sum()}")
# Out:
# COLUMN NAME: Brand                                             ATI                           0
# COLUMN NAME: Name                                              Graphics Solution             0
# COLUMN NAME: Top__GRAPHICS PROCESSOR                           CW16800-A                     0
# COLUMN NAME: Top__PIXEL SHADERS                                nan                           2375
# COLUMN NAME: Top__VERTEX SHADERS                               nan                           2574
# COLUMN NAME: Top__TMUS                                         nan                           29
# COLUMN NAME: Top__ROPS                                         nan                           25
# COLUMN NAME: Top__MEMORY SIZE                                  64 KB                         0
# COLUMN NAME: Top__MEMORY TYPE                                  DRAM                          0
# COLUMN NAME: Top__BUS WIDTH                                    32 bit                        0
# ...

# %%
df.isna().sum()
# Out:
# Brand                                      0
# Name                                       0
# Top__GRAPHICS PROCESSOR                    0
# Top__PIXEL SHADERS                      2375
# Top__VERTEX SHADERS                     2574
#                                         ...
# Theoretical Performance__TF32           3196
# Theoretical Performance__FP64 Tensor    3196
# Graphics Features__NVENC                3202
# Graphics Features__NVDEC                3202
# Mobile Graphics__Announced              3198
# Length: 134, dtype: int64
